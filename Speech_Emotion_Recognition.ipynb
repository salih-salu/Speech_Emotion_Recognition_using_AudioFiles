# %% [markdown]
# <a href="https://colab.research.google.com/github/salih-salu/Speech_Emotion_Recognition_using_AudioFiles/blob/main/Speech_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import os
import glob

import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# #Get the Dataset through google drive mounting

# %%
Dataset_path = '/content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset'
print(os.listdir(Dataset_path))
# Out:
# ['train_set', 'test_set']

# %%
train_path = os.path.join(Dataset_path, 'train_set')
test_path = os.path.join(Dataset_path, 'test_set')

print(os.listdir(train_path))
print(os.listdir(test_path))
# Out:
# ['Actor_18', 'Actor_14', 'Actor_17', 'Actor_19', 'Actor_16', 'Actor_15', 'Actor_12', 'Actor_11', 'Actor_10', 'Actor_08', 'Actor_05', 'Actor_09', 'Actor_06', 'Actor_04', 'Actor_07', 'Actor_13', 'Actor_03', 'Actor_01', 'Actor_02']
# ['Actor_22', 'Actor_24', 'Actor_23', 'Actor_20', 'Actor_21']

# %% [markdown]
# #Used glob to find all audio files from the dataset

# %%
train_files = glob.glob(
    train_path + '/**/*.wav',
    recursive=True
)

test_files = glob.glob(
    test_path + '/**/*.wav',
    recursive=True
)

# %%
print(len(train_files), len(test_files))
# Out:
# 1140 300

# %%
emotion_labels = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

# %%
def get_emotion(file_path):
    filename = os.path.basename(file_path)
    emotion_code = filename.split("-")[2]
    return emotion_labels[emotion_code]

# %%
#test emotion label using sample file from train_file

print(train_files[0])
print(get_emotion(train_files[0]))

#test emotion label using sample file from test_file

print(test_files[1])
print(get_emotion(test_files[1]))
# Out:
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/train_set/Actor_18/03-01-03-01-01-01-18.wav
# happy
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/test_set/Actor_22/03-01-06-02-01-01-22.wav
# fearful

# %% [markdown]
# #Just create the DataFrame with Audio files paths and its related labels

# %%
train_df = pd.DataFrame({
    'file_path': train_files
})

test_df = pd.DataFrame({
    'file_path': test_files
})

# %%
# train_df

# %%
train_df['emotion'] = train_df['file_path'].apply(get_emotion)

# %%
train_df
# Out:
#                                               file_path    emotion
# 0     /content/drive/MyDrive/Speech_Emotion_Recognit...      happy
# 1     /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 2     /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 3     /content/drive/MyDrive/Speech_Emotion_Recognit...        sad
# 4     /content/drive/MyDrive/Speech_Emotion_Recognit...    neutral
# ...                                                 ...        ...
# 1135  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 1136  /content/drive/MyDrive/Speech_Emotion_Recognit...    disgust
# 1137  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 1138  /content/drive/MyDrive/Speech_Emotion_Recognit...    disgust
# 1139  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
#
# [1140 rows x 2 columns]

# %%
test_df["emotion"] = test_df["file_path"].apply(get_emotion)

# %%
test_df
# Out:
#                                              file_path    emotion
# 0    /content/drive/MyDrive/Speech_Emotion_Recognit...    neutral
# 1    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 2    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 3    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 4    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# ..                                                 ...        ...
# 295  /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 296  /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 297  /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 298  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 299  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
#
# [300 rows x 2 columns]

# %%
print(train_df["emotion"].value_counts())
# Out:
# emotion
# happy        152
# calm         152
# sad          152
# fearful      152
# surprised    152
# angry        152
# disgust      152
# neutral       76
# Name: count, dtype: int64

# %%
print(test_df["emotion"].value_counts())
# Out:
# emotion
# fearful      40
# sad          40
# calm         40
# angry        40
# happy        40
# disgust      40
# surprised    40
# neutral      20
# Name: count, dtype: int64

# %% [markdown]
# #Audio processing

# %% [markdown]
# taken one sample audio for visualize the audio wave

# %%
file_path = train_df.iloc[0]["file_path"]
print(file_path)

audio, sample_rate = librosa.load(
    file_path,
    sr=16000
)

print("Sample rate:", sample_rate)
print("Audio length:", len(audio))
# Out:
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/train_set/Actor_18/03-01-03-01-01-01-18.wav
# Sample rate: 16000
# Audio length: 54455

# %%
plt.figure(figsize=(12, 4))

librosa.display.waveshow(
    audio,
    sr=sample_rate
)

plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
mfcc = librosa.feature.mfcc(
    y=audio,
    sr=sample_rate,
    n_mfcc=40
)

print(mfcc.shape)
# Out:
# (40, 107)

# %%
plt.figure(figsize=(10, 4))

librosa.display.specshow(
    mfcc,
    x_axis="time",
    sr=sample_rate
)

plt.colorbar()
plt.title("MFCC")
plt.ylabel("MFCC Coefficients")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# #MFCC Extraction for all audio files

# %% [markdown]
# Mel Frequency Cepstral Coefficients

# %%
def extract_mfcc(file_path, n_mfcc=40, max_pad_len=174):
    audio, sample_rate = librosa.load(
        file_path,
        sr=16000
    )

    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=sample_rate,
        n_mfcc=n_mfcc
    )

    if mfcc.shape[1] < max_pad_len:
        pad_width = max_pad_len - mfcc.shape[1]
        mfcc = np.pad(
            mfcc,
            pad_width=((0, 0), (0, pad_width)),
            mode='constant'
        )
    else:
        mfcc = mfcc[:, :max_pad_len]

    return mfcc

# %% [markdown]
# Create X_train and y_train

# %%
X_train = []
y_train = []

for file_path in train_df["file_path"]:
    # print(file_path)
    mfcc = extract_mfcc(file_path)

    X_train.append(mfcc)

    emotion = get_emotion(file_path)
    y_train.append(emotion)

# %% [markdown]
# Converting (X_train and y_train) List to array

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (1140, 40, 174)
# y_train shape: (1140,)

# %% [markdown]
# Create X_test and y_test

# %%
X_test = []
y_test = []

for file_path in test_df["file_path"]:

    mfcc = extract_mfcc(file_path)

    X_test.append(mfcc)

    emotion = get_emotion(file_path)
    y_test.append(emotion)

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (300, 40, 174)
# y_test shape: (300,)

# %% [markdown]
# #Converting the emotion labels (output) to numbers using LabelEncoding

# %%
encoder = LabelEncoder()

y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

print(encoder.classes_)
# Out:
# ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']

# %%
print(y_train)
# Out:
# [4 1 1 ... 7 2 7]

# %%
# print(y_test)

# %% [markdown]
# #Add CNN channel dimension

# %%
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

print(X_train.shape)
print(X_test.shape)
# Out:
# (1140, 40, 174, 1)
# (300, 40, 174, 1)

# %%
# print(X_train)

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(40, 174, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 38, 172, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 19, 86, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 17, 84, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 42, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 40, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 20, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7680)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       983,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,076,872 (4.11 MB)
#  Trainable params: 1,076,872 (4.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #Apply check point to save the best model

# %%
checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor="accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=30, callbacks=[checkpoint])
# Out:
# Epoch 1/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.1847 - loss: 7.4505
# Epoch 1: accuracy improved from None to 0.21140, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.2114 - loss: 3.8842
# Epoch 2/30
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2524 - loss: 1.8761
# Epoch 2: accuracy improved from 0.21140 to 0.25789, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2579 - loss: 1.8880
# Epoch 3/30
# 34/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2947 - loss: 1.7866
# Epoch 3: accuracy improved from 0.25789 to 0.30614, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3061 - loss: 1.7745
# Epoch 4/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3470 - loss: 1.7074
# Epoch 4: accuracy improved from 0.30614 to 0.36053, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3605 - loss: 1.6748
# Epoch 5/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3727 - loss: 1.6268
# Epoch 5: accuracy improved from 0.36053 to 0.39474, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3947 - loss: 1.5991
# Epoch 6/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4386 - loss: 1.4545
# Epoch 6: accuracy improved from 0.39474 to 0.43421, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4342 - loss: 1.4742
# Epoch 7/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4630 - loss: 1.4010
# Epoch 7: accuracy improved from 0.43421 to 0.47632, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4763 - loss: 1.3780
# Epoch 8/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4559 - loss: 1.4316
# Epoch 8: accuracy improved from 0.47632 to 0.48596, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4860 - loss: 1.3551
# Epoch 9/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5366 - loss: 1.2034
# Epoch 9: accuracy improved from 0.48596 to 0.55000, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5500 - loss: 1.2132
# Epoch 10/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5824 - loss: 1.1349
# Epoch 10: accuracy improved from 0.55000 to 0.57807, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5781 - loss: 1.1373
# Epoch 11/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6170 - loss: 1.0327
# Epoch 11: accuracy improved from 0.57807 to 0.62368, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6237 - loss: 0.9949
# Epoch 12/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6913 - loss: 0.8292
# Epoch 12: accuracy improved from 0.62368 to 0.68947, saving model to best_model.keras
#
# Epoch 12: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6895 - loss: 0.8574
# Epoch 13/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7105 - loss: 0.7819
# Epoch 13: accuracy improved from 0.68947 to 0.70439, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7044 - loss: 0.7962
# Epoch 14/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7144 - loss: 0.7647
# Epoch 14: accuracy improved from 0.70439 to 0.73070, saving model to best_model.keras
#
# Epoch 14: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7307 - loss: 0.7425
# Epoch 15/30
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7760 - loss: 0.6395
# Epoch 15: accuracy improved from 0.73070 to 0.76053, saving model to best_model.keras
#
# Epoch 15: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7605 - loss: 0.6383
# Epoch 16/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8032 - loss: 0.5262
# Epoch 16: accuracy improved from 0.76053 to 0.80000, saving model to best_model.keras
#
# Epoch 16: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - loss: 0.5671
# Epoch 17/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8152 - loss: 0.5006
# Epoch 17: accuracy did not improve from 0.80000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7930 - loss: 0.5333
# Epoch 18/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8211 - loss: 0.4762
# Epoch 18: accuracy improved from 0.80000 to 0.82018, saving model to best_model.keras
#
# Epoch 18: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8202 - loss: 0.4883
# Epoch 19/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8366 - loss: 0.4463
# Epoch 19: accuracy improved from 0.82018 to 0.84298, saving model to best_model.keras
#
# Epoch 19: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8430 - loss: 0.4465
# Epoch 20/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8499 - loss: 0.4352
# Epoch 20: accuracy improved from 0.84298 to 0.85000, saving model to best_model.keras
#
# Epoch 20: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8500 - loss: 0.4085
# Epoch 21/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8382 - loss: 0.4104
# Epoch 21: accuracy improved from 0.85000 to 0.85263, saving model to best_model.keras
#
# Epoch 21: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8526 - loss: 0.3802
# Epoch 22/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8395 - loss: 0.3959
# Epoch 22: accuracy did not improve from 0.85263
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8509 - loss: 0.3761
# Epoch 23/30
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8789 - loss: 0.3413
# Epoch 23: accuracy improved from 0.85263 to 0.87807, saving model to best_model.keras
#
# Epoch 23: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8781 - loss: 0.3282
# Epoch 24/30
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8844 - loss: 0.3232
# Epoch 24: accuracy improved from 0.87807 to 0.89123, saving model to best_model.keras
#
# Epoch 24: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8912 - loss: 0.3104
# Epoch 25/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8929 - loss: 0.2889
# Epoch 25: accuracy improved from 0.89123 to 0.89649, saving model to best_model.keras
#
# Epoch 25: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8965 - loss: 0.2847
# Epoch 26/30
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8984 - loss: 0.2694
# Epoch 26: accuracy improved from 0.89649 to 0.90789, saving model to best_model.keras
#
# Epoch 26: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9079 - loss: 0.2525
# Epoch 27/30
# 32/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8971 - loss: 0.2633
# Epoch 27: accuracy did not improve from 0.90789
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9061 - loss: 0.2457
# Epoch 28/30
# 33/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9116 - loss: 0.2438
# Epoch 28: accuracy improved from 0.90789 to 0.91754, saving model to best_model.keras
#
# Epoch 28: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9175 - loss: 0.2352
# Epoch 29/30
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9362 - loss: 0.1768
# Epoch 29: accuracy improved from 0.91754 to 0.92895, saving model to best_model.keras
#
# Epoch 29: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9289 - loss: 0.1882
# Epoch 30/30
# 32/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9311 - loss: 0.1832
# Epoch 30: accuracy improved from 0.92895 to 0.93158, saving model to best_model.keras
#
# Epoch 30: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9316 - loss: 0.1840

# %%
# model.history.history

# %%
plt.plot(model.history.history['accuracy'], model.history.history['loss'])

# %% [markdown]
# #evaluate the model performance

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(test_loss, test_accuracy)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.5133 - loss: 3.6563
# 3.6562540531158447 0.5133333206176758

# %%
y_pred = model.predict(X_test)
# for i in y_pred:
#   print(i)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step

# %%
y_pred_ind = y_pred.argmax(axis=1)
y_pred_ind
# Out:
# array([5, 3, 3, 6, 3, 6, 1, 6, 1, 1, 2, 2, 6, 1, 2, 2, 1, 6, 4, 5, 2, 1,
#        5, 3, 2, 4, 1, 7, 0, 3, 1, 2, 4, 6, 5, 6, 6, 6, 5, 6, 0, 0, 4, 0,
#        1, 0, 6, 0, 0, 2, 2, 0, 7, 7, 7, 7, 4, 7, 7, 7, 2, 1, 6, 4, 1, 1,
#        2, 4, 2, 1, 1, 0, 2, 1, 2, 1, 5, 4, 5, 1, 1, 0, 5, 1, 1, 1, 3, 2,
#        2, 1, 0, 5, 2, 0, 2, 5, 5, 4, 0, 2, 0, 0, 6, 1, 2, 2, 7, 2, 2, 7,
#        7, 7, 2, 7, 2, 2, 7, 7, 2, 2, 2, 7, 1, 7, 7, 7, 2, 7, 3, 2, 7, 1,
#        4, 2, 7, 2, 4, 7, 1, 6, 7, 3, 6, 5, 2, 6, 2, 3, 1, 1, 3, 1, 2, 1,
#        2, 1, 4, 7, 6, 1, 3, 7, 7, 7, 1, 7, 4, 7, 3, 2, 3, 7, 7, 7, 7, 7,
#        2, 7, 7, 7, 1, 1, 5, 1, 1, 1, 1, 1, 0, 1, 1, 5, 5, 4, 2, 7, 4, 2,
#        0, 2, 4, 2, 4, 7, 7, 7, 5, 4, 1, 6, 7, 2, 4, 2, 6, 1, 2, 7, 2, 6,
#        3, 2, 7, 2, 7, 7, 2, 0, 7, 7, 1, 3, 1, 5, 2, 0, 4, 1, 0, 6, 1, 1,
#        1, 1, 1, 6, 5, 4, 4, 0, 0, 0, 4, 0, 1, 1, 0, 0, 0, 1, 2, 0, 2, 0,
#        0, 0, 0, 0, 7, 1, 4, 0, 0, 7, 7, 0, 1, 0, 4, 1, 0, 0, 0, 0, 0, 5,
#        4, 4, 0, 1, 0, 0, 1, 1, 0, 6, 1, 1, 7, 0])

# %% [markdown]
# #Classification Report

# %%
crp = classification_report(y_test, y_pred_ind)
print(crp)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.60      0.55        40
#            1       0.51      0.80      0.62        40
#            2       0.53      0.70      0.60        40
#            3       0.53      0.20      0.29        40
#            4       0.48      0.33      0.39        40
#            5       0.32      0.30      0.31        20
#            6       0.48      0.28      0.35        40
#            7       0.60      0.80      0.69        40
#
#     accuracy                           0.51       300
#    macro avg       0.49      0.50      0.47       300
# weighted avg       0.51      0.51      0.49       300

# %%
print(len(y_test), len(y_pred_ind))
# Out:
# 300 300

# %%
print("Actual:   ", y_test[150])
print("Predicted: ", y_pred_ind[150])
# Out:
# Actual:    3
# Predicted:  3

# %% [markdown]
# #Accuracy Score

# %%
accuracy = accuracy_score(y_test, y_pred_ind)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.5133333333333333

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred_ind)
print(cm)
# Out:
# [[24  1  4  3  0  0  1  7]
#  [ 0 32  3  0  0  5  0  0]
#  [ 7  1 28  1  1  1  1  0]
#  [ 4  5  5  8  8  0  6  4]
#  [ 4  3  1  1 13  6  2 10]
#  [ 0 10  0  0  2  6  2  0]
#  [ 4 11 11  1  1  1 11  0]
#  [ 4  0  1  1  2  0  0 32]]

# %%
labels = list(emotion_labels.values())
print(labels)
# Out:
# ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

# %% [markdown]
# #Confusion Matrix Display

# %%
cmd = ConfusionMatrixDisplay(cm,display_labels=labels)
cmd.plot()
