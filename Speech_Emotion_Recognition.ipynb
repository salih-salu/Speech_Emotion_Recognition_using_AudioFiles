# %% [markdown]
# <a href="https://colab.research.google.com/github/salih-salu/Speech_Emotion_Recognition_using_AudioFiles/blob/main/Speech_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import os
import glob

import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# #Get the Dataset through google drive mounting

# %%
Dataset_path = '/content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset'
print(os.listdir(Dataset_path))
# Out:
# ['train_set', 'test_set']

# %%
train_path = os.path.join(Dataset_path, 'train_set')
test_path = os.path.join(Dataset_path, 'test_set')

print(os.listdir(train_path))
print(os.listdir(test_path))
# Out:
# ['Actor_18', 'Actor_14', 'Actor_17', 'Actor_19', 'Actor_16', 'Actor_15', 'Actor_12', 'Actor_11', 'Actor_10', 'Actor_08', 'Actor_05', 'Actor_09', 'Actor_06', 'Actor_04', 'Actor_07', 'Actor_13', 'Actor_03', 'Actor_01', 'Actor_02']
# ['Actor_22', 'Actor_24', 'Actor_23', 'Actor_20', 'Actor_21']

# %% [markdown]
# #Used glob to find all audio files from the dataset

# %%
train_files = glob.glob(
    train_path + '/**/*.wav',
    recursive=True
)

test_files = glob.glob(
    test_path + '/**/*.wav',
    recursive=True
)

# %%
print(len(train_files), len(test_files))
# Out:
# 1140 300

# %%
emotion_labels = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

# %%
def get_emotion(file_path):
    filename = os.path.basename(file_path)
    emotion_code = filename.split("-")[2]
    return emotion_labels[emotion_code]

# %%
#test emotion label using sample file from train_file

print(train_files[0])
print(get_emotion(train_files[0]))

#test emotion label using sample file from test_file

print(test_files[1])
print(get_emotion(test_files[1]))
# Out:
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/train_set/Actor_18/03-01-03-01-01-01-18.wav
# happy
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/test_set/Actor_22/03-01-06-02-01-01-22.wav
# fearful

# %% [markdown]
# #Just create the DataFrame with Audio files paths and its related labels

# %%
train_df = pd.DataFrame({
    'file_path': train_files
})

test_df = pd.DataFrame({
    'file_path': test_files
})

# %%
# train_df

# %%
train_df['emotion'] = train_df['file_path'].apply(get_emotion)

# %%
train_df
# Out:
#                                               file_path    emotion
# 0     /content/drive/MyDrive/Speech_Emotion_Recognit...      happy
# 1     /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 2     /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 3     /content/drive/MyDrive/Speech_Emotion_Recognit...        sad
# 4     /content/drive/MyDrive/Speech_Emotion_Recognit...    neutral
# ...                                                 ...        ...
# 1135  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 1136  /content/drive/MyDrive/Speech_Emotion_Recognit...    disgust
# 1137  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 1138  /content/drive/MyDrive/Speech_Emotion_Recognit...    disgust
# 1139  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
#
# [1140 rows x 2 columns]

# %%
test_df["emotion"] = test_df["file_path"].apply(get_emotion)

# %%
test_df
# Out:
#                                              file_path    emotion
# 0    /content/drive/MyDrive/Speech_Emotion_Recognit...    neutral
# 1    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 2    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 3    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 4    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# ..                                                 ...        ...
# 295  /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 296  /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 297  /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 298  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 299  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
#
# [300 rows x 2 columns]

# %%
print(train_df["emotion"].value_counts())
# Out:
# emotion
# happy        152
# calm         152
# sad          152
# fearful      152
# surprised    152
# angry        152
# disgust      152
# neutral       76
# Name: count, dtype: int64

# %%
print(test_df["emotion"].value_counts())
# Out:
# emotion
# fearful      40
# sad          40
# calm         40
# angry        40
# happy        40
# disgust      40
# surprised    40
# neutral      20
# Name: count, dtype: int64

# %% [markdown]
# #Audio processing

# %% [markdown]
# taken one sample audio for visualize the audio wave

# %%
file_path = train_df.iloc[0]["file_path"]
print(file_path)

audio, sample_rate = librosa.load(
    file_path,
    sr=16000
)

print("Sample rate:", sample_rate)
print("Audio length:", len(audio))
# Out:
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/train_set/Actor_18/03-01-03-01-01-01-18.wav
# Sample rate: 16000
# Audio length: 54455

# %%
plt.figure(figsize=(12, 4))

librosa.display.waveshow(
    audio,
    sr=sample_rate
)

plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
mfcc = librosa.feature.mfcc(
    y=audio,
    sr=sample_rate,
    n_mfcc=40
)

print(mfcc.shape)
# Out:
# (40, 107)

# %%
plt.figure(figsize=(10, 4))

librosa.display.specshow(
    mfcc,
    x_axis="time",
    sr=sample_rate
)

plt.colorbar()
plt.title("MFCC")
plt.ylabel("MFCC Coefficients")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# #MFCC Extraction for all audio files

# %% [markdown]
# Mel Frequency Cepstral Coefficients

# %%
def extract_mfcc(file_path, n_mfcc=40, max_pad_len=174):
    audio, sample_rate = librosa.load(
        file_path,
        sr=16000
    )

    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=sample_rate,
        n_mfcc=n_mfcc
    )

    if mfcc.shape[1] < max_pad_len:
        pad_width = max_pad_len - mfcc.shape[1]
        mfcc = np.pad(
            mfcc,
            pad_width=((0, 0), (0, pad_width)),
            mode='constant'
        )
    else:
        mfcc = mfcc[:, :max_pad_len]

    return mfcc

# %% [markdown]
# Create X_train and y_train

# %%
X_train = []
y_train = []

for file_path in train_df["file_path"]:
    # print(file_path)
    mfcc = extract_mfcc(file_path)

    X_train.append(mfcc)

    emotion = get_emotion(file_path)
    y_train.append(emotion)

# %% [markdown]
# Converting (X_train and y_train) List to array

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (1140, 40, 174)
# y_train shape: (1140,)

# %% [markdown]
# Create X_test and y_test

# %%
X_test = []
y_test = []

for file_path in test_df["file_path"]:

    mfcc = extract_mfcc(file_path)

    X_test.append(mfcc)

    emotion = get_emotion(file_path)
    y_test.append(emotion)

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (300, 40, 174)
# y_test shape: (300,)

# %% [markdown]
# #Converting the emotion labels (output) to numbers using LabelEncoding

# %%
encoder = LabelEncoder()

y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

print(encoder.classes_)
# Out:
# ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']

# %%
print(y_train)
# Out:
# [4 1 1 ... 7 2 7]

# %%
# print(y_test)

# %% [markdown]
# #Add CNN channel dimension

# %%
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

print(X_train.shape)
print(X_test.shape)
# Out:
# (1140, 40, 174, 1)
# (300, 40, 174, 1)

# %%
# print(X_train)

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(40, 174, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 38, 172, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 19, 86, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 17, 84, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 42, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 40, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 20, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7680)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       983,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,076,872 (4.11 MB)
#  Trainable params: 1,076,872 (4.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #Apply check point to save the best model

# %%
checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor="accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=50, callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.1435 - loss: 6.6955
# Epoch 1: accuracy improved from None to 0.17018, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 109ms/step - accuracy: 0.1702 - loss: 3.6862
# Epoch 2/50
# 34/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2710 - loss: 1.9321
# Epoch 2: accuracy improved from 0.17018 to 0.26754, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2675 - loss: 1.9113
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2957 - loss: 1.8340
# Epoch 3: accuracy improved from 0.26754 to 0.30965, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3096 - loss: 1.7966
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3348 - loss: 1.7143
# Epoch 4: accuracy improved from 0.30965 to 0.33421, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3342 - loss: 1.7348
# Epoch 5/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3719 - loss: 1.6606
# Epoch 5: accuracy improved from 0.33421 to 0.38509, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3851 - loss: 1.6011
# Epoch 6/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4151 - loss: 1.5082
# Epoch 6: accuracy improved from 0.38509 to 0.41404, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4140 - loss: 1.4863
# Epoch 7/50
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4924 - loss: 1.3692
# Epoch 7: accuracy improved from 0.41404 to 0.47632, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4763 - loss: 1.3905
# Epoch 8/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5167 - loss: 1.2888
# Epoch 8: accuracy improved from 0.47632 to 0.51404, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5140 - loss: 1.2813
# Epoch 9/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5331 - loss: 1.1992
# Epoch 9: accuracy improved from 0.51404 to 0.53684, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5368 - loss: 1.2022
# Epoch 10/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5709 - loss: 1.1584
# Epoch 10: accuracy improved from 0.53684 to 0.57281, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5728 - loss: 1.1500
# Epoch 11/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5676 - loss: 1.1131
# Epoch 11: accuracy improved from 0.57281 to 0.58246, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5825 - loss: 1.0653
# Epoch 12/50
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6486 - loss: 0.9372
# Epoch 12: accuracy improved from 0.58246 to 0.62895, saving model to best_model.keras
#
# Epoch 12: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6289 - loss: 0.9812
# Epoch 13/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6582 - loss: 0.8862
# Epoch 13: accuracy improved from 0.62895 to 0.67368, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6737 - loss: 0.8652
# Epoch 14/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6825 - loss: 0.8197
# Epoch 14: accuracy did not improve from 0.67368
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6632 - loss: 0.8579
# Epoch 15/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7106 - loss: 0.7811
# Epoch 15: accuracy improved from 0.67368 to 0.71316, saving model to best_model.keras
#
# Epoch 15: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7132 - loss: 0.7838
# Epoch 16/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7684 - loss: 0.6632
# Epoch 16: accuracy improved from 0.71316 to 0.73333, saving model to best_model.keras
#
# Epoch 16: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7333 - loss: 0.7324
# Epoch 17/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7359 - loss: 0.7424
# Epoch 17: accuracy improved from 0.73333 to 0.74211, saving model to best_model.keras
#
# Epoch 17: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7421 - loss: 0.7085
# Epoch 18/50
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7660 - loss: 0.6039
# Epoch 18: accuracy improved from 0.74211 to 0.75965, saving model to best_model.keras
#
# Epoch 18: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7596 - loss: 0.6312
# Epoch 19/50
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7765 - loss: 0.5522
# Epoch 19: accuracy did not improve from 0.75965
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7596 - loss: 0.5850
# Epoch 20/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7707 - loss: 0.5619
# Epoch 20: accuracy improved from 0.75965 to 0.80000, saving model to best_model.keras
#
# Epoch 20: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8000 - loss: 0.5361
# Epoch 21/50
# 34/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8389 - loss: 0.4838
# Epoch 21: accuracy did not improve from 0.80000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7947 - loss: 0.5499
# Epoch 22/50
# 34/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8236 - loss: 0.4927
# Epoch 22: accuracy improved from 0.80000 to 0.82982, saving model to best_model.keras
#
# Epoch 22: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8298 - loss: 0.4688
# Epoch 23/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8489 - loss: 0.4134
# Epoch 23: accuracy improved from 0.82982 to 0.83772, saving model to best_model.keras
#
# Epoch 23: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8377 - loss: 0.4485
# Epoch 24/50
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8184 - loss: 0.4817
# Epoch 24: accuracy did not improve from 0.83772
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8254 - loss: 0.4534
# Epoch 25/50
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8611 - loss: 0.3885
# Epoch 25: accuracy improved from 0.83772 to 0.84649, saving model to best_model.keras
#
# Epoch 25: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8465 - loss: 0.4016
# Epoch 26/50
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8560 - loss: 0.3711
# Epoch 26: accuracy improved from 0.84649 to 0.85965, saving model to best_model.keras
#
# Epoch 26: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8596 - loss: 0.3487
# Epoch 27/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8803 - loss: 0.3145
# Epoch 27: accuracy improved from 0.85965 to 0.86579, saving model to best_model.keras
#
# Epoch 27: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8658 - loss: 0.3370
# Epoch 28/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8629 - loss: 0.3456
# Epoch 28: accuracy did not improve from 0.86579
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8518 - loss: 0.3830
# Epoch 29/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8792 - loss: 0.3392
# Epoch 29: accuracy improved from 0.86579 to 0.87368, saving model to best_model.keras
#
# Epoch 29: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8737 - loss: 0.3534
# Epoch 30/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8320 - loss: 0.3884
# Epoch 30: accuracy did not improve from 0.87368
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8667 - loss: 0.3433
# Epoch 31/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8811 - loss: 0.3087
# Epoch 31: accuracy improved from 0.87368 to 0.88421, saving model to best_model.keras
#
# Epoch 31: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8842 - loss: 0.2860
# Epoch 32/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9051 - loss: 0.2909
# Epoch 32: accuracy improved from 0.88421 to 0.90263, saving model to best_model.keras
#
# Epoch 32: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9026 - loss: 0.2722
# Epoch 33/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8922 - loss: 0.2787
# Epoch 33: accuracy did not improve from 0.90263
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8868 - loss: 0.2871
# Epoch 34/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9085 - loss: 0.2406
# Epoch 34: accuracy improved from 0.90263 to 0.90526, saving model to best_model.keras
#
# Epoch 34: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9053 - loss: 0.2531
# Epoch 35/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8892 - loss: 0.2771
# Epoch 35: accuracy did not improve from 0.90526
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8965 - loss: 0.2830
# Epoch 36/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9100 - loss: 0.2456
# Epoch 36: accuracy improved from 0.90526 to 0.91842, saving model to best_model.keras
#
# Epoch 36: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9184 - loss: 0.2344
# Epoch 37/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9256 - loss: 0.2082
# Epoch 37: accuracy improved from 0.91842 to 0.92281, saving model to best_model.keras
#
# Epoch 37: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9228 - loss: 0.2262
# Epoch 38/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9081 - loss: 0.2314
# Epoch 38: accuracy did not improve from 0.92281
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9096 - loss: 0.2322
# Epoch 39/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9071 - loss: 0.2267
# Epoch 39: accuracy did not improve from 0.92281
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9114 - loss: 0.2231
# Epoch 40/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9396 - loss: 0.1626
# Epoch 40: accuracy improved from 0.92281 to 0.92719, saving model to best_model.keras
#
# Epoch 40: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9272 - loss: 0.1951
# Epoch 41/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9111 - loss: 0.2358
# Epoch 41: accuracy did not improve from 0.92719
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9167 - loss: 0.2166
# Epoch 42/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9168 - loss: 0.2081
# Epoch 42: accuracy improved from 0.92719 to 0.93860, saving model to best_model.keras
#
# Epoch 42: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9386 - loss: 0.1795
# Epoch 43/50
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9262 - loss: 0.1854
# Epoch 43: accuracy did not improve from 0.93860
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9184 - loss: 0.2077
# Epoch 44/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9393 - loss: 0.1463
# Epoch 44: accuracy did not improve from 0.93860
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9325 - loss: 0.1659
# Epoch 45/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9412 - loss: 0.1720
# Epoch 45: accuracy improved from 0.93860 to 0.93947, saving model to best_model.keras
#
# Epoch 45: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9395 - loss: 0.1737
# Epoch 46/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9259 - loss: 0.1886
# Epoch 46: accuracy did not improve from 0.93947
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9281 - loss: 0.1853
# Epoch 47/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9401 - loss: 0.1624
# Epoch 47: accuracy did not improve from 0.93947
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9289 - loss: 0.1901
# Epoch 48/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9395 - loss: 0.1611
# Epoch 48: accuracy did not improve from 0.93947
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9281 - loss: 0.1684
# Epoch 49/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9477 - loss: 0.1426
# Epoch 49: accuracy improved from 0.93947 to 0.95263, saving model to best_model.keras
#
# Epoch 49: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9526 - loss: 0.1304
# Epoch 50/50
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9438 - loss: 0.1391
# Epoch 50: accuracy did not improve from 0.95263
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9439 - loss: 0.1340

# %%
# model.history.history

# %%
plt.plot(model.history.history['accuracy'], model.history.history['loss'])

# %% [markdown]
# #evaluate the model performance

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(test_loss, test_accuracy)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.4333 - loss: 5.6946
# 5.694558143615723 0.4333333373069763

# %%
y_pred = model.predict(X_test)
# for i in y_pred:
#   print(i)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step

# %%
y_pred_ind = y_pred.argmax(axis=1)
y_pred_ind
# Out:
# array([5, 6, 6, 3, 3, 6, 5, 1, 1, 1, 4, 1, 6, 6, 4, 2, 5, 6, 3, 4, 0, 6,
#        5, 3, 0, 7, 5, 3, 0, 0, 1, 1, 3, 6, 5, 0, 6, 1, 5, 6, 0, 0, 4, 0,
#        4, 0, 6, 4, 0, 0, 0, 0, 7, 0, 7, 7, 7, 7, 7, 7, 2, 6, 6, 0, 1, 1,
#        2, 4, 2, 1, 1, 0, 0, 2, 2, 1, 5, 4, 6, 1, 1, 0, 3, 5, 1, 1, 2, 6,
#        2, 1, 0, 5, 2, 6, 2, 5, 1, 0, 0, 2, 4, 0, 6, 1, 7, 2, 0, 0, 2, 7,
#        0, 7, 0, 7, 2, 4, 7, 7, 2, 2, 2, 7, 1, 7, 7, 7, 2, 7, 7, 2, 7, 1,
#        4, 2, 7, 1, 6, 7, 2, 6, 7, 4, 2, 5, 2, 2, 2, 3, 2, 2, 6, 2, 2, 2,
#        2, 1, 4, 3, 6, 1, 3, 7, 7, 7, 2, 7, 0, 7, 4, 2, 7, 7, 7, 7, 7, 7,
#        0, 7, 7, 7, 5, 1, 7, 1, 1, 1, 6, 1, 0, 6, 5, 7, 0, 7, 2, 0, 4, 2,
#        7, 2, 0, 2, 0, 7, 0, 7, 6, 0, 6, 2, 7, 6, 2, 2, 6, 1, 2, 5, 7, 4,
#        6, 2, 3, 7, 7, 7, 2, 0, 7, 7, 6, 7, 6, 5, 2, 0, 4, 1, 0, 7, 1, 2,
#        1, 1, 1, 1, 6, 4, 0, 0, 0, 0, 4, 0, 2, 1, 3, 0, 0, 1, 0, 0, 2, 0,
#        0, 7, 0, 0, 7, 2, 4, 7, 0, 7, 7, 0, 0, 0, 4, 2, 0, 0, 0, 2, 0, 6,
#        1, 0, 0, 1, 2, 2, 2, 1, 0, 6, 1, 1, 7, 7])

# %% [markdown]
# #Classification Report

# %%
crp = classification_report(y_test, y_pred_ind)
print(crp)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      0.55      0.43        40
#            1       0.63      0.68      0.65        40
#            2       0.32      0.42      0.37        40
#            3       0.42      0.12      0.19        40
#            4       0.29      0.15      0.20        40
#            5       0.50      0.40      0.44        20
#            6       0.33      0.28      0.30        40
#            7       0.57      0.85      0.68        40
#
#     accuracy                           0.43       300
#    macro avg       0.43      0.43      0.41       300
# weighted avg       0.42      0.43      0.41       300

# %%
print(len(y_test), len(y_pred_ind))
# Out:
# 300 300

# %%
print("Actual:   ", y_test[150])
print("Predicted: ", y_pred_ind[150])
# Out:
# Actual:    3
# Predicted:  6

# %% [markdown]
# #Accuracy Score

# %%
accuracy = accuracy_score(y_test, y_pred_ind)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.43333333333333335

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred_ind)
print(cm)
# Out:
# [[22  0  2  2  3  0  2  9]
#  [ 0 27  5  0  0  4  3  1]
#  [15  1 17  0  3  1  1  2]
#  [ 6  1  7  5  8  0 10  3]
#  [ 9  3  4  4  6  2  2 10]
#  [ 2  2  3  0  0  8  4  1]
#  [ 4  9 15  0  1  0 11  0]
#  [ 4  0  0  1  0  1  0 34]]

# %%
labels = list(emotion_labels.values())
print(labels)
# Out:
# ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

# %% [markdown]
# #Confusion Matrix Display

# %%
cmd = ConfusionMatrixDisplay(cm,display_labels=labels)
cmd.plot()
