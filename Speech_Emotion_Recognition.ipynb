# %% [markdown]
# <a href="https://colab.research.google.com/github/salih-salu/Speech_Emotion_Recognition_using_AudioFiles/blob/main/Speech_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import os
import glob

import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# #Get the Dataset through google drive mounting

# %%
Dataset_path = '/content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset'
print(os.listdir(Dataset_path))
# Out:
# ['train_set', 'test_set']

# %%
train_path = os.path.join(Dataset_path, 'train_set')
test_path = os.path.join(Dataset_path, 'test_set')

print(os.listdir(train_path))
print(os.listdir(test_path))
# Out:
# ['Actor_18', 'Actor_14', 'Actor_17', 'Actor_19', 'Actor_16', 'Actor_15', 'Actor_12', 'Actor_11', 'Actor_10', 'Actor_08', 'Actor_05', 'Actor_09', 'Actor_06', 'Actor_04', 'Actor_07', 'Actor_13', 'Actor_03', 'Actor_01', 'Actor_02']
# ['Actor_22', 'Actor_24', 'Actor_23', 'Actor_20', 'Actor_21']

# %% [markdown]
# #Used glob to find all audio files from the dataset

# %%
train_files = glob.glob(
    train_path + '/**/*.wav',
    recursive=True
)

test_files = glob.glob(
    test_path + '/**/*.wav',
    recursive=True
)

# %%
print(len(train_files), len(test_files))
# Out:
# 1140 300

# %%
emotion_labels = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

# %%
def get_emotion(file_path):
    filename = os.path.basename(file_path)
    emotion_code = filename.split("-")[2]
    return emotion_labels[emotion_code]

# %%
#test emotion label using sample file from train_file

print(train_files[0])
print(get_emotion(train_files[0]))

#test emotion label using sample file from test_file

print(test_files[1])
print(get_emotion(test_files[1]))
# Out:
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/train_set/Actor_18/03-01-03-01-01-01-18.wav
# happy
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/test_set/Actor_22/03-01-06-02-01-01-22.wav
# fearful

# %% [markdown]
# #Just create the DataFrame with Audio files paths and its related labels

# %%
train_df = pd.DataFrame({
    'file_path': train_files
})

test_df = pd.DataFrame({
    'file_path': test_files
})

# %%
# train_df

# %%
train_df['emotion'] = train_df['file_path'].apply(get_emotion)

# %%
train_df
# Out:
#                                               file_path    emotion
# 0     /content/drive/MyDrive/Speech_Emotion_Recognit...      happy
# 1     /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 2     /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 3     /content/drive/MyDrive/Speech_Emotion_Recognit...        sad
# 4     /content/drive/MyDrive/Speech_Emotion_Recognit...    neutral
# ...                                                 ...        ...
# 1135  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 1136  /content/drive/MyDrive/Speech_Emotion_Recognit...    disgust
# 1137  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 1138  /content/drive/MyDrive/Speech_Emotion_Recognit...    disgust
# 1139  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
#
# [1140 rows x 2 columns]

# %%
test_df["emotion"] = test_df["file_path"].apply(get_emotion)

# %%
test_df
# Out:
#                                              file_path    emotion
# 0    /content/drive/MyDrive/Speech_Emotion_Recognit...    neutral
# 1    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 2    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 3    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 4    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# ..                                                 ...        ...
# 295  /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 296  /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 297  /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 298  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 299  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
#
# [300 rows x 2 columns]

# %%
print(train_df["emotion"].value_counts())
# Out:
# emotion
# happy        152
# calm         152
# sad          152
# fearful      152
# surprised    152
# angry        152
# disgust      152
# neutral       76
# Name: count, dtype: int64

# %%
print(test_df["emotion"].value_counts())
# Out:
# emotion
# fearful      40
# sad          40
# calm         40
# angry        40
# happy        40
# disgust      40
# surprised    40
# neutral      20
# Name: count, dtype: int64

# %% [markdown]
# #Audio processing

# %% [markdown]
# taken one sample audio for visualize the audio wave

# %%
file_path = train_df.iloc[0]["file_path"]
print(file_path)

audio, sample_rate = librosa.load(
    file_path,
    sr=16000
)

print("Sample rate:", sample_rate)
print("Audio length:", len(audio))
# Out:
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/train_set/Actor_18/03-01-03-01-01-01-18.wav
# Sample rate: 16000
# Audio length: 54455

# %%
plt.figure(figsize=(12, 4))

librosa.display.waveshow(
    audio,
    sr=sample_rate
)

plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
mfcc = librosa.feature.mfcc(
    y=audio,
    sr=sample_rate,
    n_mfcc=40
)

print(mfcc.shape)
# Out:
# (40, 107)

# %%
plt.figure(figsize=(10, 4))

librosa.display.specshow(
    mfcc,
    x_axis="time",
    sr=sample_rate
)

plt.colorbar()
plt.title("MFCC")
plt.ylabel("MFCC Coefficients")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# #MFCC Extraction for all audio files

# %% [markdown]
# Mel Frequency Cepstral Coefficients

# %%
def extract_mfcc(file_path, n_mfcc=40, max_pad_len=174):
    audio, sample_rate = librosa.load(
        file_path,
        sr=16000
    )

    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=sample_rate,
        n_mfcc=n_mfcc
    )

    if mfcc.shape[1] < max_pad_len:
        pad_width = max_pad_len - mfcc.shape[1]
        mfcc = np.pad(
            mfcc,
            pad_width=((0, 0), (0, pad_width)),
            mode='constant'
        )
    else:
        mfcc = mfcc[:, :max_pad_len]

    return mfcc

# %% [markdown]
# Create X_train and y_train

# %%
X_train = []
y_train = []

for file_path in train_df["file_path"]:
    # print(file_path)
    mfcc = extract_mfcc(file_path)

    X_train.append(mfcc)

    emotion = get_emotion(file_path)
    y_train.append(emotion)

# %% [markdown]
# Converting (X_train and y_train) List to array

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (1140, 40, 174)
# y_train shape: (1140,)

# %% [markdown]
# Create X_test and y_test

# %%
X_test = []
y_test = []

for file_path in test_df["file_path"]:

    mfcc = extract_mfcc(file_path)

    X_test.append(mfcc)

    emotion = get_emotion(file_path)
    y_test.append(emotion)

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (300, 40, 174)
# y_test shape: (300,)

# %% [markdown]
# #Converting the emotion labels (output) to numbers using LabelEncoding

# %%
encoder = LabelEncoder()

y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

print(encoder.classes_)
# Out:
# ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']

# %%
print(y_train)
# Out:
# [4 1 1 ... 7 2 7]

# %%
# print(y_test)

# %% [markdown]
# #Add CNN channel dimension

# %%
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

print(X_train.shape)
print(X_test.shape)
# Out:
# (1140, 40, 174, 1)
# (300, 40, 174, 1)

# %%
# print(X_train)

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(40, 174, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 38, 172, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 19, 86, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 17, 84, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 42, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 40, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 20, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7680)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       983,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,076,872 (4.11 MB)
#  Trainable params: 1,076,872 (4.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #Apply check point to save the best model

# %%
checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor="accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=25, callbacks=[checkpoint])
# Out:
# Epoch 1/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.1576 - loss: 4.5003
# Epoch 1: accuracy improved from None to 0.17982, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.1798 - loss: 2.8400
# Epoch 2/25
# 34/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2230 - loss: 1.9226
# Epoch 2: accuracy improved from 0.17982 to 0.23947, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.2395 - loss: 1.9025
# Epoch 3/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3001 - loss: 1.7854
# Epoch 3: accuracy improved from 0.23947 to 0.31140, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3114 - loss: 1.7731
# Epoch 4/25
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3224 - loss: 1.7178
# Epoch 4: accuracy improved from 0.31140 to 0.33684, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3368 - loss: 1.6850
# Epoch 5/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3519 - loss: 1.6323
# Epoch 5: accuracy improved from 0.33684 to 0.37281, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3728 - loss: 1.5808
# Epoch 6/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4716 - loss: 1.4132
# Epoch 6: accuracy improved from 0.37281 to 0.46228, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4623 - loss: 1.4350
# Epoch 7/25
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4915 - loss: 1.3464
# Epoch 7: accuracy improved from 0.46228 to 0.50877, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5088 - loss: 1.3297
# Epoch 8/25
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4867 - loss: 1.2835
# Epoch 8: accuracy improved from 0.50877 to 0.51667, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5167 - loss: 1.2157
# Epoch 9/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5422 - loss: 1.1705
# Epoch 9: accuracy improved from 0.51667 to 0.54386, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5439 - loss: 1.1452
# Epoch 10/25
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6210 - loss: 0.9819
# Epoch 10: accuracy improved from 0.54386 to 0.60526, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6053 - loss: 1.0290
# Epoch 11/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6388 - loss: 1.0111
# Epoch 11: accuracy improved from 0.60526 to 0.65351, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6535 - loss: 0.9655
# Epoch 12/25
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6729 - loss: 0.8446
# Epoch 12: accuracy improved from 0.65351 to 0.65789, saving model to best_model.keras
#
# Epoch 12: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6579 - loss: 0.8585
# Epoch 13/25
# 29/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6758 - loss: 0.8009
# Epoch 13: accuracy improved from 0.65789 to 0.68509, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6851 - loss: 0.7930
# Epoch 14/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7210 - loss: 0.7114
# Epoch 14: accuracy improved from 0.68509 to 0.71491, saving model to best_model.keras
#
# Epoch 14: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7149 - loss: 0.7355
# Epoch 15/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7461 - loss: 0.6559
# Epoch 15: accuracy improved from 0.71491 to 0.74298, saving model to best_model.keras
#
# Epoch 15: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7430 - loss: 0.6721
# Epoch 16/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7652 - loss: 0.6210
# Epoch 16: accuracy did not improve from 0.74298
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7395 - loss: 0.6781
# Epoch 17/25
# 32/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7559 - loss: 0.6028
# Epoch 17: accuracy improved from 0.74298 to 0.76667, saving model to best_model.keras
#
# Epoch 17: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7667 - loss: 0.5830
# Epoch 18/25
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7571 - loss: 0.5767
# Epoch 18: accuracy improved from 0.76667 to 0.78596, saving model to best_model.keras
#
# Epoch 18: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7860 - loss: 0.5255
# Epoch 19/25
# 30/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8053 - loss: 0.4794
# Epoch 19: accuracy improved from 0.78596 to 0.80965, saving model to best_model.keras
#
# Epoch 19: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8096 - loss: 0.4920
# Epoch 20/25
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8140 - loss: 0.4388
# Epoch 20: accuracy improved from 0.80965 to 0.82982, saving model to best_model.keras
#
# Epoch 20: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8298 - loss: 0.4376
# Epoch 21/25
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8446 - loss: 0.3757
# Epoch 21: accuracy improved from 0.82982 to 0.85088, saving model to best_model.keras
#
# Epoch 21: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8509 - loss: 0.3932
# Epoch 22/25
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8599 - loss: 0.3684
# Epoch 22: accuracy improved from 0.85088 to 0.85263, saving model to best_model.keras
#
# Epoch 22: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8526 - loss: 0.3855
# Epoch 23/25
# 31/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8708 - loss: 0.3389
# Epoch 23: accuracy improved from 0.85263 to 0.85526, saving model to best_model.keras
#
# Epoch 23: finished saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8553 - loss: 0.3772
# Epoch 24/25
# 34/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8629 - loss: 0.3838
# Epoch 24: accuracy did not improve from 0.85526
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8518 - loss: 0.3762
# Epoch 25/25
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8575 - loss: 0.3291
# Epoch 25: accuracy did not improve from 0.85526
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8526 - loss: 0.3508

# %%
# model.history.history

# %%
plt.plot(model.history.history['accuracy'], model.history.history['loss'])

# %% [markdown]
# #evaluate the model performance

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(test_loss, test_accuracy)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.5367 - loss: 2.7407
# 2.7407288551330566 0.5366666913032532

# %%
y_pred = model.predict(X_test)
# for i in y_pred:
#   print(i)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step

# %%
y_pred_ind = y_pred.argmax(axis=1)
y_pred_ind
# Out:
# array([5, 3, 6, 6, 3, 4, 1, 6, 1, 1, 2, 2, 6, 6, 2, 2, 1, 6, 4, 5, 2, 6,
#        1, 3, 0, 4, 6, 4, 0, 6, 5, 1, 4, 6, 6, 7, 6, 1, 2, 1, 0, 7, 7, 0,
#        2, 0, 6, 6, 0, 2, 2, 4, 7, 7, 7, 7, 7, 7, 7, 7, 2, 5, 6, 0, 1, 1,
#        3, 3, 2, 6, 1, 0, 3, 4, 2, 1, 5, 4, 1, 1, 1, 0, 5, 1, 1, 1, 0, 6,
#        2, 1, 0, 6, 2, 0, 2, 5, 1, 4, 0, 2, 4, 0, 6, 1, 4, 2, 7, 2, 2, 7,
#        7, 7, 7, 7, 2, 2, 7, 7, 2, 0, 1, 7, 1, 7, 7, 7, 2, 7, 7, 2, 7, 1,
#        7, 2, 7, 2, 4, 7, 4, 1, 7, 4, 6, 6, 2, 6, 2, 4, 2, 1, 6, 6, 2, 2,
#        2, 2, 4, 4, 6, 1, 7, 7, 7, 7, 1, 5, 4, 7, 3, 1, 7, 7, 7, 7, 7, 7,
#        2, 7, 7, 7, 1, 1, 5, 1, 1, 1, 1, 1, 4, 1, 1, 1, 6, 7, 1, 0, 4, 2,
#        0, 2, 0, 2, 4, 7, 4, 7, 6, 4, 6, 6, 7, 6, 2, 2, 6, 1, 2, 5, 2, 6,
#        6, 2, 7, 2, 6, 7, 3, 0, 7, 7, 6, 7, 6, 4, 2, 0, 4, 5, 0, 7, 1, 2,
#        1, 6, 1, 6, 5, 4, 0, 0, 0, 0, 0, 0, 2, 2, 7, 4, 0, 1, 0, 0, 2, 5,
#        0, 7, 0, 0, 7, 1, 4, 7, 2, 7, 7, 0, 2, 0, 4, 2, 0, 0, 2, 4, 0, 4,
#        4, 0, 0, 1, 6, 0, 1, 1, 0, 6, 1, 1, 7, 7])

# %% [markdown]
# #Classification Report

# %%
crp = classification_report(y_test, y_pred_ind)
print(crp)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.55      0.54        40
#            1       0.61      0.78      0.68        40
#            2       0.52      0.68      0.59        40
#            3       1.00      0.20      0.33        40
#            4       0.44      0.35      0.39        40
#            5       0.38      0.25      0.30        20
#            6       0.38      0.38      0.38        40
#            7       0.63      0.97      0.76        40
#
#     accuracy                           0.54       300
#    macro avg       0.56      0.52      0.50       300
# weighted avg       0.57      0.54      0.51       300

# %%
print(len(y_test), len(y_pred_ind))
# Out:
# 300 300

# %%
print("Actual:   ", y_test[150])
print("Predicted: ", y_pred_ind[150])
# Out:
# Actual:    3
# Predicted:  6

# %% [markdown]
# #Accuracy Score

# %%
accuracy = accuracy_score(y_test, y_pred_ind)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.5366666666666666

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred_ind)
print(cm)
# Out:
# [[22  0  4  0  2  0  2 10]
#  [ 0 31  4  0  0  2  3  0]
#  [ 7  0 27  0  2  1  3  0]
#  [ 5  3  1  8 11  1 10  1]
#  [ 5  2  2  0 14  2  3 12]
#  [ 0  7  1  0  3  5  4  0]
#  [ 3  8 13  0  0  1 15  0]
#  [ 0  0  0  0  0  1  0 39]]

# %%
labels = list(emotion_labels.values())
print(labels)
# Out:
# ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

# %% [markdown]
# #Confusion Matrix Display

# %%
cmd = ConfusionMatrixDisplay(cm,display_labels=labels)
cmd.plot()
