# %% [markdown]
# <a href="https://colab.research.google.com/github/salih-salu/Speech_Emotion_Recognition_using_AudioFiles/blob/main/Speech_Emotion_Recognition_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import os
import glob

import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# #Get the Dataset through google drive mounting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Dataset_path = '/content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset'
print(os.listdir(Dataset_path))
# Out:
# ['train_set', 'test_set']

# %%
train_path = os.path.join(Dataset_path, 'train_set')
test_path = os.path.join(Dataset_path, 'test_set')

print(os.listdir(train_path))
print(os.listdir(test_path))
# Out:
# ['Actor_18', 'Actor_14', 'Actor_17', 'Actor_19', 'Actor_16', 'Actor_15', 'Actor_12', 'Actor_11', 'Actor_10', 'Actor_08', 'Actor_05', 'Actor_09', 'Actor_06', 'Actor_04', 'Actor_07', 'Actor_13', 'Actor_03', 'Actor_01', 'Actor_02']
# ['Actor_22', 'Actor_24', 'Actor_23', 'Actor_20', 'Actor_21']

# %% [markdown]
# #Used glob to find all audio files from the dataset

# %%
train_files = glob.glob(
    train_path + '/**/*.wav',
    recursive=True
)

test_files = glob.glob(
    test_path + '/**/*.wav',
    recursive=True
)

# %%
print(len(train_files), len(test_files))
# Out:
# 1140 300

# %%
emotion_labels = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

# %%
def get_emotion(file_path):
    filename = os.path.basename(file_path)
    emotion_code = filename.split("-")[2]
    return emotion_labels[emotion_code]

# %%
#test emotion label using sample file from train_file

print(train_files[0])
print(get_emotion(train_files[0]))

#test emotion label using sample file from test_file

print(test_files[1])
print(get_emotion(test_files[1]))
# Out:
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/train_set/Actor_18/03-01-03-01-01-01-18.wav
# happy
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/test_set/Actor_22/03-01-06-02-01-01-22.wav
# fearful

# %% [markdown]
# #Just create the DataFrame with Audio files paths and its related labels

# %%
train_df = pd.DataFrame({
    'file_path': train_files
})

test_df = pd.DataFrame({
    'file_path': test_files
})

# %%
# train_df

# %%
train_df['emotion'] = train_df['file_path'].apply(get_emotion)

# %%
train_df
# Out:
#                                               file_path    emotion
# 0     /content/drive/MyDrive/Speech_Emotion_Recognit...      happy
# 1     /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 2     /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 3     /content/drive/MyDrive/Speech_Emotion_Recognit...        sad
# 4     /content/drive/MyDrive/Speech_Emotion_Recognit...    neutral
# ...                                                 ...        ...
# 1135  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 1136  /content/drive/MyDrive/Speech_Emotion_Recognit...    disgust
# 1137  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 1138  /content/drive/MyDrive/Speech_Emotion_Recognit...    disgust
# 1139  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
#
# [1140 rows x 2 columns]

# %%
test_df["emotion"] = test_df["file_path"].apply(get_emotion)

# %%
test_df
# Out:
#                                              file_path    emotion
# 0    /content/drive/MyDrive/Speech_Emotion_Recognit...    neutral
# 1    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 2    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 3    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 4    /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# ..                                                 ...        ...
# 295  /content/drive/MyDrive/Speech_Emotion_Recognit...    fearful
# 296  /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 297  /content/drive/MyDrive/Speech_Emotion_Recognit...       calm
# 298  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
# 299  /content/drive/MyDrive/Speech_Emotion_Recognit...  surprised
#
# [300 rows x 2 columns]

# %%
print(train_df["emotion"].value_counts())
# Out:
# emotion
# happy        152
# calm         152
# sad          152
# fearful      152
# surprised    152
# angry        152
# disgust      152
# neutral       76
# Name: count, dtype: int64

# %%
print(test_df["emotion"].value_counts())
# Out:
# emotion
# fearful      40
# sad          40
# calm         40
# angry        40
# happy        40
# disgust      40
# surprised    40
# neutral      20
# Name: count, dtype: int64

# %% [markdown]
# #Audio processing

# %% [markdown]
# taken one sample audio for visualize the audio wave

# %%
file_path = train_df.iloc[0]["file_path"]
print(file_path)

audio, sample_rate = librosa.load(
    file_path,
    sr=16000
)

print("Sample rate:", sample_rate)
print("Audio length:", len(audio))
# Out:
# /content/drive/MyDrive/Speech_Emotion_Recognition/Speech_emo_dataset/train_set/Actor_18/03-01-03-01-01-01-18.wav
# Sample rate: 16000
# Audio length: 54455

# %%
plt.figure(figsize=(12, 4))

librosa.display.waveshow(
    audio,
    sr=sample_rate
)

plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
mfcc = librosa.feature.mfcc(
    y=audio,
    sr=sample_rate,
    n_mfcc=40
)

print(mfcc.shape)
# Out:
# (40, 107)

# %%
plt.figure(figsize=(10, 4))

librosa.display.specshow(
    mfcc,
    x_axis="time",
    sr=sample_rate
)

plt.colorbar()
plt.title("MFCC")
plt.ylabel("MFCC Coefficients")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# #Data augmentation functions

# %%
def add_noise(audio, noise_factor=0.005):
    noise = np.random.randn(len(audio))
    return audio + noise_factor * noise


def shift_audio(audio, shift_max=0.2):
    shift = int(np.random.uniform(-shift_max, shift_max) * len(audio))
    return np.roll(audio, shift)


def change_pitch(audio, sr, n_steps=2):
    return librosa.effects.pitch_shift(
        y=audio,
        sr=sr,
        n_steps=n_steps
    )

# %% [markdown]
# #MFCC Extraction for all audio files

# %% [markdown]
# Mel Frequency Cepstral Coefficients

# %%
def extract_mfcc(file_path, n_mfcc=40, max_pad_len=174):
    audio, sample_rate = librosa.load(
        file_path,
        sr=16000
    )

    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=sample_rate,
        n_mfcc=n_mfcc
    )

    if mfcc.shape[1] < max_pad_len:
        pad_width = max_pad_len - mfcc.shape[1]
        mfcc = np.pad(
            mfcc,
            pad_width=((0, 0), (0, pad_width)),
            mode='constant'
        )
    else:
        mfcc = mfcc[:, :max_pad_len]

    return mfcc

# ........................................................................................................
# ........................................................................................................


def extract_mfcc_augmented(file_path, n_mfcc=40, max_pad_len=174):

    audio, sr = librosa.load(
        file_path,
        sr=16000
    )

    # Randomly choose one augmentation
    choice = np.random.choice(
        ["original", "noise", "shift", "pitch"]
    )

    if choice == "noise":
        audio = add_noise(audio)

    elif choice == "shift":
        audio = shift_audio(audio)

    elif choice == "pitch":
        audio = change_pitch(audio, sr, n_steps=2)

    # MFCC
    mfcc = librosa.feature.mfcc(
        y=audio,
        sr=sr,
        n_mfcc=n_mfcc
    )

    # Padding / trimming
    if mfcc.shape[1] < max_pad_len:

        pad_width = max_pad_len - mfcc.shape[1]

        mfcc = np.pad(
            mfcc,
            ((0, 0), (0, pad_width)),
            mode='constant'
        )

    else:
        mfcc = mfcc[:, :max_pad_len]

    return mfcc

# %% [markdown]
# Create X_train and y_train

# %%
# X_train = []
# y_train = []

# for file_path in train_df["file_path"]:
#     # print(file_path)
#     mfcc = extract_mfcc(file_path)

#     X_train.append(mfcc)

#     emotion = get_emotion(file_path)
#     y_train.append(emotion)

X_train_aug = []
y_train_aug = []

for file_path in train_df["file_path"]:

    # Original audio
    mfcc = extract_mfcc_augmented(file_path)

    X_train_aug.append(mfcc)
    y_train_aug.append(get_emotion(file_path))

    # One additional augmented version
    mfcc_aug = extract_mfcc_augmented(file_path)

    X_train_aug.append(mfcc_aug)
    y_train_aug.append(get_emotion(file_path))


X_train_aug = np.array(X_train_aug)
y_train_aug = np.array(y_train_aug)

print("X_train_aug:", X_train_aug.shape)
print("y_train_aug:", y_train_aug.shape)
# Out:
# X_train_aug: (2280, 40, 174)
# y_train_aug: (2280,)

# %%
# Calculate mean and standard deviation from training data only
mean = X_train_aug.mean()
std = X_train_aug.std()

# Normalize training and testing data
X_train = (X_train_aug - mean) / (std + 1e-8)
X_test = (X_train_aug - mean) / (std + 1e-8)

print("Before normalization:")
print("Mean:", X_train_aug.mean())
print("Std:", X_train_aug.std())

print("\nAfter normalization:")
print("Mean:", X_train.mean())
print("Std:", X_train.std())
# Out:
# Before normalization:
# Mean: -8.318444637940983
# Std: 72.41230752647947
#
# After normalization:
# Mean: 1.591055489728593e-16
# Std: 0.9999999998619018

# %% [markdown]
# Converting (X_train and y_train) List to array

# %%
# X_train = np.array(X_train)
# y_train = np.array(y_train)

X_train = np.array(X_train_aug)
y_train = np.array(y_train_aug)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (2280, 40, 174)
# y_train shape: (2280,)

# %% [markdown]
# Create X_test and y_test

# %%
X_test = []
y_test = []

for file_path in test_df["file_path"]:

    mfcc = extract_mfcc(file_path)

    X_test.append(mfcc)

    emotion = get_emotion(file_path)
    y_test.append(emotion)

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (300, 40, 174)
# y_test shape: (300,)

# %% [markdown]
# #Converting the emotion labels (output) to numbers using LabelEncoding

# %%
encoder = LabelEncoder()

y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

print(encoder.classes_)
# Out:
# ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']

# %%
print(y_train)
# Out:
# [4 4 1 ... 2 7 7]

# %%
# print(y_test)

# %% [markdown]
# #Add CNN channel dimension

# %%
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

print(X_train.shape)
print(X_test.shape)
# Out:
# (2280, 40, 174, 1)
# (300, 40, 174, 1)

# %%
# print(X_train)

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(40, 174, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 38, 172, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 19, 86, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 17, 84, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 42, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 40, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 20, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7680)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       983,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,076,872 (4.11 MB)
#  Trainable params: 1,076,872 (4.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #Apply check point to save the best model

# %%
checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor="accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=25, callbacks=[checkpoint])
# Out:
# Epoch 1/25
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1792 - loss: 3.8254
# Epoch 1: accuracy improved from None to 0.20570, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.2057 - loss: 2.4828
# Epoch 2/25
# 70/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2311 - loss: 1.9242
# Epoch 2: accuracy improved from 0.20570 to 0.24912, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2491 - loss: 1.9097
# Epoch 3/25
# 70/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2799 - loss: 1.8255
# Epoch 3: accuracy improved from 0.24912 to 0.29825, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2982 - loss: 1.7858
# Epoch 4/25
# 68/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3056 - loss: 1.7326
# Epoch 4: accuracy improved from 0.29825 to 0.32544, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3254 - loss: 1.7195
# Epoch 5/25
# 66/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3882 - loss: 1.6159
# Epoch 5: accuracy improved from 0.32544 to 0.38421, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3842 - loss: 1.6138
# Epoch 6/25
# 67/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4326 - loss: 1.4886
# Epoch 6: accuracy improved from 0.38421 to 0.43728, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4373 - loss: 1.4515
# Epoch 7/25
# 67/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4748 - loss: 1.3759
# Epoch 7: accuracy improved from 0.43728 to 0.47588, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4759 - loss: 1.3719
# Epoch 8/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4934 - loss: 1.3189
# Epoch 8: accuracy improved from 0.47588 to 0.52368, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5237 - loss: 1.2650
# Epoch 9/25
# 70/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5659 - loss: 1.1288
# Epoch 9: accuracy improved from 0.52368 to 0.54518, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5452 - loss: 1.1647
# Epoch 10/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5553 - loss: 1.1408
# Epoch 10: accuracy improved from 0.54518 to 0.56272, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5627 - loss: 1.1250
# Epoch 11/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5862 - loss: 1.0675
# Epoch 11: accuracy improved from 0.56272 to 0.58991, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5899 - loss: 1.0528
# Epoch 12/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5870 - loss: 0.9998
# Epoch 12: accuracy improved from 0.58991 to 0.59912, saving model to best_model.keras
#
# Epoch 12: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5991 - loss: 0.9799
# Epoch 13/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5816 - loss: 1.0126
# Epoch 13: accuracy improved from 0.59912 to 0.62018, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6202 - loss: 0.9545
# Epoch 14/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6573 - loss: 0.8290
# Epoch 14: accuracy improved from 0.62018 to 0.64167, saving model to best_model.keras
#
# Epoch 14: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6417 - loss: 0.8599
# Epoch 15/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6584 - loss: 0.9032
# Epoch 15: accuracy improved from 0.64167 to 0.67368, saving model to best_model.keras
#
# Epoch 15: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6737 - loss: 0.8560
# Epoch 16/25
# 70/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7195 - loss: 0.7130
# Epoch 16: accuracy improved from 0.67368 to 0.71754, saving model to best_model.keras
#
# Epoch 16: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7175 - loss: 0.7133
# Epoch 17/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7151 - loss: 0.6875
# Epoch 17: accuracy did not improve from 0.71754
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7175 - loss: 0.6818
# Epoch 18/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7559 - loss: 0.6432
# Epoch 18: accuracy improved from 0.71754 to 0.74781, saving model to best_model.keras
#
# Epoch 18: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7478 - loss: 0.6529
# Epoch 19/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7493 - loss: 0.6237
# Epoch 19: accuracy improved from 0.74781 to 0.75482, saving model to best_model.keras
#
# Epoch 19: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7548 - loss: 0.6193
# Epoch 20/25
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7753 - loss: 0.5488
# Epoch 20: accuracy improved from 0.75482 to 0.76579, saving model to best_model.keras
#
# Epoch 20: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7658 - loss: 0.5685
# Epoch 21/25
# 70/72 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7631 - loss: 0.5878
# Epoch 21: accuracy improved from 0.76579 to 0.77281, saving model to best_model.keras
#
# Epoch 21: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7728 - loss: 0.5716
# Epoch 22/25
# 68/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8042 - loss: 0.5026
# Epoch 22: accuracy improved from 0.77281 to 0.80614, saving model to best_model.keras
#
# Epoch 22: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8061 - loss: 0.4861
# Epoch 23/25
# 67/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8073 - loss: 0.4781
# Epoch 23: accuracy did not improve from 0.80614
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8044 - loss: 0.4852
# Epoch 24/25
# 67/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8345 - loss: 0.4852
# Epoch 24: accuracy improved from 0.80614 to 0.83596, saving model to best_model.keras
#
# Epoch 24: finished saving model to best_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8360 - loss: 0.4465
# Epoch 25/25
# 69/72 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8238 - loss: 0.4395
# Epoch 25: accuracy did not improve from 0.83596
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8259 - loss: 0.4288

# %%
# model.history.history

# %%
plt.plot(model.history.history['accuracy'], model.history.history['loss'])

# %% [markdown]
# #evaluate the model performance

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(test_loss, test_accuracy)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5467 - loss: 3.2817
# 3.2817068099975586 0.54666668176651

# %%
y_pred = model.predict(X_test)
# for i in y_pred:
#   print(i)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step

# %%
y_pred_ind = y_pred.argmax(axis=1)
y_pred_ind
# Out:
# array([4, 3, 3, 4, 6, 4, 1, 6, 1, 1, 0, 1, 4, 3, 0, 0, 1, 6, 4, 4, 4, 6,
#        1, 3, 0, 7, 1, 4, 0, 0, 6, 1, 4, 6, 4, 0, 4, 6, 1, 1, 0, 0, 4, 0,
#        4, 0, 6, 0, 0, 0, 0, 4, 7, 0, 7, 7, 7, 7, 7, 7, 1, 1, 3, 4, 1, 1,
#        4, 4, 2, 1, 1, 0, 3, 3, 2, 1, 5, 4, 1, 5, 1, 0, 4, 5, 1, 1, 0, 3,
#        2, 1, 3, 4, 2, 0, 2, 4, 2, 3, 0, 0, 0, 0, 3, 5, 3, 2, 7, 2, 2, 7,
#        7, 7, 7, 7, 2, 0, 7, 7, 2, 2, 1, 7, 2, 7, 7, 3, 2, 7, 0, 0, 7, 1,
#        4, 2, 3, 2, 4, 7, 0, 5, 7, 4, 2, 2, 6, 2, 2, 4, 1, 1, 2, 6, 2, 1,
#        2, 1, 3, 0, 2, 1, 0, 7, 3, 7, 1, 7, 4, 7, 4, 1, 0, 7, 7, 7, 7, 7,
#        2, 7, 7, 7, 2, 1, 5, 6, 1, 1, 1, 1, 4, 1, 5, 2, 6, 7, 2, 0, 4, 2,
#        0, 2, 0, 0, 4, 4, 2, 7, 1, 2, 6, 6, 7, 2, 6, 2, 6, 1, 4, 7, 2, 6,
#        7, 2, 7, 7, 4, 7, 4, 0, 7, 4, 6, 7, 4, 6, 2, 0, 4, 1, 0, 0, 1, 2,
#        1, 1, 1, 1, 5, 0, 0, 0, 0, 0, 0, 0, 2, 2, 7, 0, 0, 1, 0, 0, 2, 0,
#        0, 7, 0, 0, 7, 1, 0, 7, 0, 7, 7, 0, 2, 0, 0, 2, 0, 0, 0, 2, 0, 2,
#        0, 4, 0, 1, 0, 0, 2, 1, 0, 2, 1, 1, 7, 7])

# %% [markdown]
# #Classification Report

# %%
crp = classification_report(y_test, y_pred_ind)
print(crp)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.75      0.56        40
#            1       0.67      0.85      0.75        40
#            2       0.45      0.53      0.48        40
#            3       0.69      0.28      0.39        40
#            4       0.39      0.38      0.38        40
#            5       0.50      0.20      0.29        20
#            6       0.58      0.28      0.37        40
#            7       0.72      0.95      0.82        40
#
#     accuracy                           0.55       300
#    macro avg       0.55      0.53      0.50       300
# weighted avg       0.56      0.55      0.52       300

# %%
print(len(y_test), len(y_pred_ind))
# Out:
# 300 300

# %%
print("Actual:   ", y_test[150])
print("Predicted: ", y_pred_ind[150])
# Out:
# Actual:    3
# Predicted:  2

# %% [markdown]
# #Accuracy Score

# %%
accuracy = accuracy_score(y_test, y_pred_ind)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.5466666666666666

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred_ind)
print(cm)
# Out:
# [[30  0  3  1  1  0  0  5]
#  [ 0 34  1  0  1  2  2  0]
#  [15  0 21  0  3  0  0  1]
#  [ 6  1  6 11 12  0  3  1]
#  [ 9  0  4  3 15  1  1  7]
#  [ 1  6  3  0  4  4  2  0]
#  [ 6 10  9  1  1  1 11  1]
#  [ 1  0  0  0  1  0  0 38]]

# %%
labels = list(emotion_labels.values())
print(labels)
# Out:
# ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

# %% [markdown]
# #Confusion Matrix Display

# %%
cmd = ConfusionMatrixDisplay(cm,display_labels=labels)
cmd.plot()

# %% [markdown]
# #Test an audio file via uploading.

# %%
# from google.colab import files

# uploaded = files.upload()

# %%
# def extract_mfcc_for_prediction(file_path, n_mfcc=40, max_pad_len=174):
#     audio, sample_rate = librosa.load(
#         file_path,
#         sr=16000
#     )
#     mfcc = librosa.feature.mfcc(
#         y=audio,
#         sr=sample_rate,
#         n_mfcc=n_mfcc
#     )

#     if mfcc.shape[1] < max_pad_len:
#         pad_width = max_pad_len - mfcc.shape[1]
#         mfcc = np.pad(
#             mfcc,
#             ((0, 0), (0, pad_width)),
#             mode='constant'
#         )
#     else:
#         mfcc = mfcc[:, :max_pad_len]

#     return mfcc

# %%
# # file_path = list(uploaded.keys())[0]
# file_path = '/content/03-01-08-02-02-01-21.wav'

# mfcc = extract_mfcc_for_prediction(file_path)
# mfcc = mfcc[np.newaxis, ..., np.newaxis]
# prediction = model.predict(mfcc)
# predicted_class = np.argmax(prediction, axis=1)[0]

# predicted_emotion = encoder.inverse_transform([predicted_class])[0]
# confidence = np.max(prediction) * 100

# print("Predicted Emotion:", predicted_emotion)
# print("Confidence:", round(confidence, 2), "%")

# %%
# The above prediction is correct for the uploaded audio file.

# %%
plt.plot(model.history.history['accuracy'])
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
train_accuracy = model.history.history['accuracy'][-1]

test_loss, test_accuracy = model.evaluate(
    X_test,
    y_test,
    verbose=0
)

print("Training Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.8258771896362305
# Test Accuracy: 0.54666668176651
